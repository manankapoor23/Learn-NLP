# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (2025.9.18)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (4.67.1)
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 24.5 MB/s  0:00:00
# Installing collected packages: nltk
# Successfully installed nltk-3.9.2
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
corpus = "my name is manan kapoor. i study in Islamabad . I am a student"

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/manankapoor/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize
print(sent_tokenize(corpus))
# Out:
# ['my name is manan kapoor.', 'i study in Islamabad .', 'I am a student']

# %%
from nltk.tokenize import word_tokenize
print(word_tokenize(corpus))
# Out:
# ['my', 'name', 'is', 'manan', 'kapoor', '.', 'i', 'study', 'in', 'Islamabad', '.', 'I', 'am', 'a', 'student']

# %%
from nltk.tokenize import wordpunct_tokenize
print(wordpunct_tokenize(corpus))
# Out:
# ['my', 'name', 'is', 'manan', 'kapoor', '.', 'i', 'study', 'in', 'Islamabad', '.', 'I', 'am', 'a', 'student']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['my',
#  'name',
#  'is',
#  'manan',
#  'kapoor.',
#  'i',
#  'study',
#  'in',
#  'Islamabad',
#  '.',
#  'I',
#  'am',
#  'a',
#  'student']
