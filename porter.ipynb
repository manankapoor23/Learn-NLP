# %%
# !pip install nltk
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from nltk.stem import PorterStemmer
prt = PorterStemmer()
prt.stem("Eating",to_lowercase=False)
# Out:
# 'Eate'
